# %% [markdown]
# # Assignment 5

# %% [markdown]
# ### Objective

# %% [raw]
# Learn how to connect to social media network (we will use Twitter as example in this assignment), and collect/preprocess/analyze its data
#
#
# Tweets Data Can be used for different purposes by marketing department and data analytics team. For example:
#
# - Compete with rivals to offer price-match gaurantee policy
# - Offer same coupons like rivals in the market place

# %% [markdown]
# ### Installation and Setup

# %% [raw]
# For this assignment you need to do the following setup first:
#
# 1.  Create an account on twitter.com.
#
# 2.  Generate authentication tokens by following the instructions here :
#     https://dev.twitter.com/oauth/overview/application-owner-access-tokens
#
# 3.  Add your tokens to the credentials.txt file.

# %% [markdown]
# ### Twitter API

# %% [raw]
# Twitter API
#
# Two APIs:
#
#     REST API: Submit HTTP requests to access specific information (tweets, friends, ...)
#     Streaming API: Open a continuous connection to Twitter to receive real-time data.
#
# These APIs are  HTTP GET request
#
#
#
#
# Here are the twitter API docs that you must familiarize yourself with
#
# https://dev.twitter.com/rest/reference/get/followers/ids
#
# https://dev.twitter.com/overview/api/twitter-libraries

# %% [raw]
# When you search in a text (tweets are text messages), often you need to be aware of something STOP WORDS.
# You could read more about stop-words here:
#
#     https://en.wikipedia.org/wiki/Stop_words

# %% [markdown]
# # Lets create twitter object and use its API. Code snippets below will show you how to use this API

# %%
from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterRestPager

# %%
o = TwitterOAuth.read_file('credentials.txt')

# %%
o.access_token_key
# Out:
# '592894800-BOc2g80oqx3KbGFIOzYatFwnsYBumWbDoxLGsMAW'

# %%
# Using OAuth1...
twitter = TwitterAPI(o.consumer_key,
                 o.consumer_secret,
                 o.access_token_key,
                 o.access_token_secret)

# %%
help(twitter)
# Out:
# Help on TwitterAPI in module TwitterAPI.TwitterAPI object:
#
# class TwitterAPI(__builtin__.object)
#  |  Access REST API or Streaming API resources.
#  |
#  |  :param consumer_key: Twitter application consumer key
#  |  :param consumer_secret: Twitter application consumer secret
#  |  :param access_token_key: Twitter application access token key
#  |  :param access_token_secret: Twitter application access token secret
#  |  :param auth_type: "oAuth1" (default) or "oAuth2"
#  |  :param proxy_url: HTTPS proxy URL (ex. "https://USER:PASSWORD@SERVER:PORT")
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type='oAuth1', proxy_url=None)
#  |      Initialize with your Twitter application credentials
#  |
#  |  request(self, resource, params=None, files=None, method_override=None)
#  |      Request a Twitter REST API or Streaming API resource.
#  |
#  |      :param resource: A valid Twitter endpoint (ex. "search/tweets")
#  |      :param params: Dictionary with endpoint parameters or None (default)
#  |      :param files: Dictionary with multipart-encoded file or None (default)
#  |      :param method_override: Request method to override or None (default)
#  |
#  |      :returns: TwitterResponse
#  |      :raises: TwitterConnectionError
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# What can we do with this twitter object?
# builtin method `dir` tells us...
dir(twitter)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_endpoint',
#  '_prepare_url',
#  'auth',
#  'proxies',
#  'request']

# %%
twitter.auth

# %%
# Get help on the `request` method using the builtin method called...`help`
help(twitter.request)
# Out:
# Help on method request in module TwitterAPI.TwitterAPI:
#
# request(self, resource, params=None, files=None, method_override=None) method of TwitterAPI.TwitterAPI.TwitterAPI instance
#     Request a Twitter REST API or Streaming API resource.
#
#     :param resource: A valid Twitter endpoint (ex. "search/tweets")
#     :param params: Dictionary with endpoint parameters or None (default)
#     :param files: Dictionary with multipart-encoded file or None (default)
#     :param method_override: Request method to override or None (default)
#
#     :returns: TwitterResponse
#     :raises: TwitterConnectionError

# %%
# Let's start by querying the search API
response = twitter.request('search/tweets', {'q': 'big+data'})

# %%
# What object is returned?
# builtin type method will tell us.
print type(response)
dir(response)
# Out:
# <class 'TwitterAPI.TwitterAPI.TwitterResponse'>
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'close',
#  'get_iterator',
#  'get_rest_quota',
#  'headers',
#  'json',
#  'response',
#  'status_code',
#  'stream',
#  'text']

# %%
response.json
# Out:
# <bound method TwitterResponse.json of <TwitterAPI.TwitterAPI.TwitterResponse object at 0x0000000008D49F28>>

# %%
response.status_code
# See https://dev.twitter.com/overview/api/response-codes
# Out:
# 200

# %%
tweets = [r for r in response]

# %%
print('found %d tweets' % len(tweets))
# Out:
# found 9 tweets

# %%
type(tweets)
# Out:
# list

# %%
type(tweets[0])
# Out:
# dict

# %%
tweets[0]
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Sat Dec 02 03:55:41 +0000 2017',
#  u'entities': {u'hashtags': [],
#   u'symbols': [],
#   u'urls': [{u'display_url': u'forbes.com/sites/kellyphi\u2026',
#     u'expanded_url': u'https://www.forbes.com/sites/kellyphillipserb/2017/11/29/irs-nabs-big-win-over-coinbase-in-bid-for-bitcoin-customer-data/#5bd63ac259af',
#     u'indices': [76, 99],
#     u'url': u'https://t.co/LNMEteYArN'}],
#   u'user_mentions': [{u'id': 91478624,
#     u'id_str': u'91478624',
#     u'indices': [68, 75],
#     u'name': u'Forbes',
#     u'screen_name': u'Forbes'}]},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 936806046001119232L,
#  u'id_str': u'936806046001119232',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'is_quote_status': False,
#  u'lang': u'en',
#  u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#  u'place': None,
#  u'possibly_sensitive': False,
#  u'retweet_count': 0,
#  u'retweeted': False,
#  u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  u'text': u'IRS Nabs Big Win Over Coinbase In Bid For Bitcoin Customer Data via @forbes https://t.co/LNMEteYArN',
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Mon Oct 13 20:10:36 +0000 2014',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u"Get Free Gift Cards. Start with 500 points with my invite code: 'ACVTLG '. https://t.co/A8X7gqImjW\U0001f4b0\U0001f4b0\U0001f4b0",
#   u'entities': {u'description': {u'urls': [{u'display_url': u'app.irazoo.com',
#       u'expanded_url': u'https://app.irazoo.com',
#       u'indices': [75, 98],
#       u'url': u'https://t.co/A8X7gqImjW'}]}},
#   u'favourites_count': 330,
#   u'follow_request_sent': False,
#   u'followers_count': 4098,
#   u'following': False,
#   u'friends_count': 3933,
#   u'geo_enabled': False,
#   u'has_extended_profile': False,
#   u'id': 2828241268L,
#   u'id_str': u'2828241268',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 74,
#   u'location': u'ohio',
#   u'name': u'Charles',
#   u'notifications': False,
#   u'profile_background_color': u'000000',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2828241268/1432705459',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/521755808715907073/ir4j4Ewd_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/521755808715907073/ir4j4Ewd_normal.jpeg',
#   u'profile_link_color': u'1B95E0',
#   u'profile_sidebar_border_color': u'000000',
#   u'profile_sidebar_fill_color': u'000000',
#   u'profile_text_color': u'000000',
#   u'profile_use_background_image': False,
#   u'protected': False,
#   u'screen_name': u'cdlrtydevil',
#   u'statuses_count': 16380,
#   u'time_zone': u'Pacific Time (US & Canada)',
#   u'translator_type': u'none',
#   u'url': None,
#   u'utc_offset': -28800,
#   u'verified': False}}

# %%
help(tweets[0])
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __init__(...)
#  |      x.__init__(...) initializes x; see help(type(x)) for signature
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(...)
#  |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#  |      v defaults to None.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  has_key(...)
#  |      D.has_key(k) -> True if D has a key k, else False
#  |
#  |  items(...)
#  |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#  |
#  |  iteritems(...)
#  |      D.iteritems() -> an iterator over the (key, value) items of D
#  |
#  |  iterkeys(...)
#  |      D.iterkeys() -> an iterator over the keys of D
#  |
#  |  itervalues(...)
#  |      D.itervalues() -> an iterator over the values of D
#  |
#  |  keys(...)
#  |      D.keys() -> list of D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E present and has a .keys() method, does:     for k in E: D[k] = E[k]
#  |      If E present and lacks .keys() method, does:     for (k, v) in E: D[k] = v
#  |      In either case, this is followed by: for k in F: D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> list of D's values
#  |
#  |  viewitems(...)
#  |      D.viewitems() -> a set-like object providing a view on D's items
#  |
#  |  viewkeys(...)
#  |      D.viewkeys() -> a set-like object providing a view on D's keys
#  |
#  |  viewvalues(...)
#  |      D.viewvalues() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %%
tweets[0].keys()
# Out:
# [u'contributors',
#  u'truncated',
#  u'text',
#  u'is_quote_status',
#  u'in_reply_to_status_id',
#  u'id',
#  u'favorite_count',
#  u'entities',
#  u'retweeted',
#  u'coordinates',
#  u'source',
#  u'in_reply_to_screen_name',
#  u'in_reply_to_user_id',
#  u'retweet_count',
#  u'id_str',
#  u'favorited',
#  u'user',
#  u'geo',
#  u'in_reply_to_user_id_str',
#  u'possibly_sensitive',
#  u'lang',
#  u'created_at',
#  u'in_reply_to_status_id_str',
#  u'place',
#  u'metadata']

# %%
tweets[0]['text']
# Out:
# u'IRS Nabs Big Win Over Coinbase In Bid For Bitcoin Customer Data via @forbes https://t.co/LNMEteYArN'

# %%
tweets[0]['created_at']
# Out:
# u'Sat Dec 02 03:55:41 +0000 2017'

# %%
tweets[5]['text']
# Out:
# u'RT @NYTScience: An idea for creating air or fuel from the Martian atmosphere led to a breakthrough in powering big data centers https://t.c\u2026'

# %%
tweets[0]['user']
# Out:
# {u'contributors_enabled': False,
#  u'created_at': u'Mon Oct 13 20:10:36 +0000 2014',
#  u'default_profile': False,
#  u'default_profile_image': False,
#  u'description': u"Get Free Gift Cards. Start with 500 points with my invite code: 'ACVTLG '. https://t.co/A8X7gqImjW\U0001f4b0\U0001f4b0\U0001f4b0",
#  u'entities': {u'description': {u'urls': [{u'display_url': u'app.irazoo.com',
#      u'expanded_url': u'https://app.irazoo.com',
#      u'indices': [75, 98],
#      u'url': u'https://t.co/A8X7gqImjW'}]}},
#  u'favourites_count': 330,
#  u'follow_request_sent': False,
#  u'followers_count': 4098,
#  u'following': False,
#  u'friends_count': 3933,
#  u'geo_enabled': False,
#  u'has_extended_profile': False,
#  u'id': 2828241268L,
#  u'id_str': u'2828241268',
#  u'is_translation_enabled': False,
#  u'is_translator': False,
#  u'lang': u'en',
#  u'listed_count': 74,
#  u'location': u'ohio',
#  u'name': u'Charles',
#  u'notifications': False,
#  u'profile_background_color': u'000000',
#  u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#  u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#  u'profile_background_tile': False,
#  u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2828241268/1432705459',
#  u'profile_image_url': u'http://pbs.twimg.com/profile_images/521755808715907073/ir4j4Ewd_normal.jpeg',
#  u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/521755808715907073/ir4j4Ewd_normal.jpeg',
#  u'profile_link_color': u'1B95E0',
#  u'profile_sidebar_border_color': u'000000',
#  u'profile_sidebar_fill_color': u'000000',
#  u'profile_text_color': u'000000',
#  u'profile_use_background_image': False,
#  u'protected': False,
#  u'screen_name': u'cdlrtydevil',
#  u'statuses_count': 16380,
#  u'time_zone': u'Pacific Time (US & Canada)',
#  u'translator_type': u'none',
#  u'url': None,
#  u'utc_offset': -28800,
#  u'verified': False}

# %%
user = tweets[0]['user']
print('screen_name=%s, name=%s, location=%s' % (user['screen_name'], user['name'], user['location']))
# Out:
# screen_name=cdlrtydevil, name=Charles, location=ohio

# %%
# Who follows this person?
# https://dev.twitter.com/docs/api/1.1/get/followers/list
screen_name = user['screen_name']
response  = twitter.request('followers/list', {'screen_name': screen_name, 'count':200})
followers = [follower for follower in response]
        
print 'found %d followers for %s' % (len(followers), screen_name)
# See more about paging here: https://dev.twitter.com/docs/working-with-timelines
# Out:
# found 200 followers for cdlrtydevil

# %%
print followers[0]['screen_name']
# Out:
# mercy_animal

# %% [markdown]
# ##  Limitations:       Can only search 2 weeks in past         But can get up to 3,200 most recent tweets of a user     Rate limits! https://dev.twitter.com/docs/rate-limiting/1.1/limits         e.g., 180 requests in 15 minute window

# %% [markdown]
# # Get Deals timeline for the deals screen-name
#
# # This is the screen name for Deals

# %%
# Get DealsPlus timeline = ''
screen_name = 'DealsPlus'
timeline = [tweet for tweet in twitter.request('statuses/user_timeline',
                                                {'screen_name': screen_name,
                                                 'count': 200})]
print 'got %d tweets for user %s' % (len(timeline), screen_name)
# Out:
# got 200 tweets for user DealsPlus

# %%
# Print time got created.

timeline[3]['created_at']
# Out:
# u'Sat Dec 02 02:00:50 +0000 2017'

# %%
# Print the text.
print '\n\n\n'.join(t['text'] for t in timeline)
# Get Deals: https://t.co/MAZR21SSzC https://t.co/tXtFboaNzM
#
#
# Save $100 On Galaxy Tab S2 8”
#
# Get Deal: https://t.co/TEkxmz07ej
#
# (Reg. $349.99) https://t.co/Z88X9yId8D
#
#
# Walmart's Cyber Monday sale is live!
#
# Shop Now: https://t.co/qDuGK8Bz5x https://t.co/Vt4n1PKBQC
#
#
# 40% Off Everything + Free Shipping
#
# Shop Now: https://t.co/1Il0gVi5fR https://t.co/iuwiyfZhrf
#
#
# Best TV Deals for Cyber Monday
#
# Get Deals: https://t.co/BPfSgr1Q4Y https://t.co/UpnGrur99n
#
#
# Mobile TV Floor Cart w/ Wheels (32" to 70")
#
# Ships Free: https://t.co/8Zag9cXDiG https://t.co/EkN0mkyLr0
#
#
# Need a  new tablet? Best Cyber Monday Deals
#
# See Deals: https://t.co/gbvke5eHrZ https://t.co/b3xuURz8WI
#
#
# Cyber Monday | 50% Off Sitewide + Free Shipping
#
# See the sale: https://t.co/00PZAyDy65 https://t.co/7BDNZnQvKs

# %%
# Count words
from collections import Counter  # This is just a fancy dict mapping from object->int, starting at 0.
counts = Counter()
for tweet in timeline:
    counts.update(tweet['text'].lower().split())
print('found %d unique terms in %d tweets' % (len(counts), len(timeline)))
counts.most_common(10)
# Out:
# found 1294 unique terms in 200 tweets
# [(u'off', 49),
#  (u'only', 48),
#  (u'free', 39),
#  (u'see', 39),
#  (u'for', 39),
#  (u'+', 38),
#  (u'(reg', 33),
#  (u'cyber', 24),
#  (u'&amp;', 24),
#  (u'|', 23)]

# %%
import re
for tweet in timeline:
    deal = tweet['text']
    print deal + '\n'
# Out:
# Only $20 for Large Gold Fireplace Screen 4 Panel
#
# See this: https://t.co/FyvkCMxThI https://t.co/iEbvauRLnu
#
# Free 3-Month SiriusXM Trial w/ Amazon Account
#
# See the offer: https://t.co/VPVVu5Wpzf https://t.co/gQUacwVi5z
#
# $48 for Columbia Cascade Ridge Bonded Softshell Jacket (4 Colors)
#
# Check it: https://t.co/442D8E3GV4 https://t.co/pnlqyRa6Mr
#
# $70 for Jordan Men's AJ 1 High Sneakers + More
#
# Check out: https://t.co/4oTuyS2tng https://t.co/Adm51S8ujV
#
# Free SmartScan Express App
#
# Check out: https://t.co/0GO5EOP4eW https://t.co/Ai6vimPJgZ
#
# Women's Clearance Outerwear from $7 | Walmart
#
# See this: https://t.co/0FoNJmFpgY https://t.co/3IgsiofDKB
#
# 4 Colleges Offering Tuition-free Programs
#
# READ HERE: https://t.co/NqZOTv8TAI https://t.co/pzyCpiD0Tj
#
# Over $7,500 Instant Holiday Savings
#
# SEE DEALS: https://t.co/M8otMuKyoh https://t.co/so7YwVR8gB
#
# Prepaid Samsung Luna Pro 16GB Smartphone
#
# Only $29.99: https://t.co/LbyjLerHxw
#
# (Reg $79) https://t.co/LlG9exyrWz
#
# Corelle 6-Pc Livingware Plate Set
#
# Only $1.99 Each: https://t.co/rZGFCbE3dw
#
# (Reg $13.99) https://t.co/x6mm4dfORJ
#
# Just $22.48: https://t.co/pReeuVNtIk https://t.co/mDgjypyeDD
#
# Best Clothing &amp; Shoe Deals for Cyber Monday
#
# See Deals: https://t.co/zfjOUdf07s https://t.co/gBxCmsqFJZ
#
# 20% Off Cyber Week Sale + Extra $10 Off $50
#
# See Sale: https://t.co/d7CTXP54P2 https://t.co/wq1HntSuM7
#
# Best Laptop &amp; Macbook Deals for Cyber Monday
#
# SEE DEALS: https://t.co/YtnaD6TtT9 https://t.co/JAOq0mz9lw
#
# Insignia Computer Speakers
#
# Just $7.49 + Ships FREE: https://t.co/PVE8mBrGTX https://t.co/wZVKurbih8
#
# Best Cyber Monday Cell Phone Deals &amp; Sales
#
# See Deals: https://t.co/Wi3nUgAqjC https://t.co/7oJZqd4zxX
#
# Up To 50% Off HP’s Cyber Week Sale!
#
# Get Deals: https://t.co/MAZR21SSzC https://t.co/tXtFboaNzM
#
# Save $100 On Galaxy Tab S2 8”
#
# Get Deal: https://t.co/TEkxmz07ej
#
# (Reg. $349.99) https://t.co/Z88X9yId8D
#
# Walmart's Cyber Monday sale is live!
#
# Shop Now: https://t.co/qDuGK8Bz5x https://t.co/Vt4n1PKBQC
#
# 40% Off Everything + Free Shipping
#
# Shop Now: https://t.co/1Il0gVi5fR https://t.co/iuwiyfZhrf
#
# Best TV Deals for Cyber Monday
#
# Get Deals: https://t.co/BPfSgr1Q4Y https://t.co/UpnGrur99n
#
# Mobile TV Floor Cart w/ Wheels (32" to 70")
#
# Ships Free: https://t.co/8Zag9cXDiG https://t.co/EkN0mkyLr0
#
# Need a  new tablet? Best Cyber Monday Deals
#
# See Deals: https://t.co/gbvke5eHrZ https://t.co/b3xuURz8WI
#
# Cyber Monday | 50% Off Sitewide + Free Shipping
#
# See the sale: https://t.co/00PZAyDy65 https://t.co/7BDNZnQvKs

# %% [markdown]
# # Find  the deals in the DealPlus tweets  that match products in BestDeal MySQL product table

# %%
import re
import pymysql

cnx = pymysql.connect(user='root', password='Qwerty1!',
                              host='127.0.0.1',
                              database='falcon')
cursor = cnx.cursor()

query = ("SELECT name FROM products")
cursor.execute(query)


dealMatchGauranteed=[]
for product in cursor:
    for tweet in timeline:
        deal = (tweet['text']).encode('ascii','ignore')
        if (len(re.findall(r'\s'+product[0]+'\s',deal)) >= 1):
            dealMatchGauranteed = dealMatchGauranteed + [deal]

# %%
# Sanity Test that  we got some deals
dealMatchGauranteed[:5]
# Out:
# ["$14.99 Men's Dress Shirts | Macy's\n\nGET DEAL: https://t.co/foPfdIEBM8\n\n(Reg $60) https://t.co/n0THG7eTTW",
#  '$48 for Columbia Cascade Ridge Bonded Softshell Jacket (4 Colors)\n\nCheck it: https://t.co/442D8E3GV4 https://t.co/pnlqyRa6Mr']

# %% [markdown]
# # Create and write the deals into DealMatches.txt file that will be used by web-app of BestDeal to display two deal matches

# %%
dealMatchFile = open('DealMatches.txt', 'w')

for deal in dealMatchGauranteed:
  dealMatchFile.write("%s\n" % deal)

dealMatchFile.close()
